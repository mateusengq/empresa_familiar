# %% [markdown]
# # Avaliação _ Empresas Familiares

# %%
import numpy as np
import pandas as pd

# %%
# Leitura dos dados
df = pd.read_csv('dados/base_empresas_v2.csv', sep = ';', encoding='latin-1')

# %%
# Seleção das colunas de interesse

df_2 = df[['Empresa', 'Principais Executivos']]

# %%
# Separação das colunas
base = df_2['Principais Executivos'].str.split(",", expand = True)

# %%
print(f'A base original possui {df_2.shape} dimensoes e a nova, {base.shape}')
# Out:
# A base original possui (7883, 2) dimensoes e a nova, (7883, 100)

# %%
## Agrupando as bases

df_3 = pd.concat([df_2, base], axis = 1)

# %%
df_3.shape
# Out:
# (7883, 102)

# %%
# df_3

# %%
df_3 = df_3.drop(columns=['Principais Executivos'])

# %%
# Transformando o formato do dataframe para longer considerando apenas a relação empresa-aconista_x
df_4 = pd.melt(
    frame = df_3,
    id_vars = ['Empresa'],
    var_name = 'coluna_referencia',
    value_name = 'Acionista'
)

# %%
df_4.shape
# Out:
# (788300, 3)

# %%
df_4
# Out:
#                                                   Empresa coluna_referencia  \
# 0           Reply do Brasil Sistemas de Informatica Ltda.                 0
# 1            Cadillac Fairview Brasil Participacoes Ltda.                 0
# 2                              Competition Academia Ltda.                 0
# 3       Quickly Travel Agencia de Viagens e Turismo Ltda.                 0
# 4                       Glr Consultoria em Sistemas Ltda.                 0
# ...                                                   ...               ...
# 788295            Cmo Construcao e Montagem Offshore S.A.                99
# 788296             Cervejaria Independente Vera Cruz S.A.                99
# 788297         Canamor Agro - Industrial e Mercantil S/A.                99
# 788298       Azimut Brasil Wealth Management Holding S.A.                99
# 788299  Aureon Ind e Com de Equipamentos Eletronicos L...                99
#
#                              Acionista
# 0                 @Logistics Reply Srl
# 1                  1699516 Ontario Inc
# 2             2Xfr Participacoes Ltda.
# 3              3Mf Participacoes Ltda.
# 4       3r Capital Participacoes Ltda.
# ...                                ...
# 788295                            None
# 788296                            None
# 788297                            None
# 788298                            None
# 788299                             NaN
#
# [788300 rows x 3 columns]

# %%
# Exclusão dos valores ausentes

df_4 = df_4.dropna()

# %%
# Contagem da quantidade de acionistas de cada empresa
## qtde_acionistas_por_empresas = df_4.groupby(['Empresa'])['Empresa'].count()

qtde_acionistas_por_empresas= df_4.groupby(['Empresa']).size().reset_index(name = 'count')

# %%
qtde_acionistas_por_empresas
# Out:
#                                                 Empresa  count
# 0                 1 1 A Flacipel Remocoes de Lixo Ltda.      2
# 1                 1000 X Servicos Administrativos Ltda.      1
# 2        13A Informatica e Material de Escritorio Ltda.      2
# 3               2001 Servicos de Entregas Rapidas Ltda.      1
# 4        2Easy Servicos de Processamento de Dados Ltda.      3
# ...                                                 ...    ...
# 5695                 Zunzal Comercio de Alimentos Ltda.      3
# 5696          Zurcher Kantonalbank Representacoes Ltda.      1
# 5697                   Zurich Brasil Capitalizacao S.A.      2
# 5698                  Zurich Industria e Comercio Ltda.      3
# 5699  Zwilling J.A.Henckels Brasil Produtos de Cozin...      2
#
# [5700 rows x 2 columns]

# %%
# Sepração dos nomes das colunas de acionistas

df_5 = df_4['Acionista'].str.split(expand = True)

# %%
df_5
# Out:
#                 0              1              2          3        4     5   \
# 0       @Logistics          Reply            Srl       None     None  None
# 1          1699516        Ontario            Inc       None     None  None
# 2             2Xfr  Participacoes          Ltda.       None     None  None
# 3              3Mf  Participacoes          Ltda.       None     None  None
# 4               3r        Capital  Participacoes      Ltda.     None  None
# ...            ...            ...            ...        ...      ...   ...
# 772634       Paula       Cristina       Penteado  Magalhaes  Azevedo  None
# 772690       Lucas      Menicelli      Lagonegro       None     None  None
# 780462     Luciano      Bernardes        Alberto      Silva     None  None
# 780517       Paulo           Jose     Cavalcante    Santana     None  None
# 780573       Lucas        Silvino       Craveiro       None     None  None
#
#           6     7     8     9     10    11    12    13
# 0       None  None  None  None  None  None  None  None
# 1       None  None  None  None  None  None  None  None
# 2       None  None  None  None  None  None  None  None
# 3       None  None  None  None  None  None  None  None
# 4       None  None  None  None  None  None  None  None
# ...      ...   ...   ...   ...   ...   ...   ...   ...
# 772634  None  None  None  None  None  None  None  None
# 772690  None  None  None  None  None  None  None  None
# 780462  None  None  None  None  None  None  None  None
# 780517  None  None  None  None  None  None  None  None
# 780573  None  None  None  None  None  None  None  None
#
# [15782 rows x 14 columns]

# %%
# Combinando os dois dataframes

df_5 = pd.concat([df_4, df_5], axis = 1)

# %%
# Selecionando as colunas de interesse e realizando o pivot longer

df_5 = df_5.drop(columns=['coluna_referencia', 'Acionista'])

# %%
df_5
# Out:
#                                                   Empresa           0  \
# 0           Reply do Brasil Sistemas de Informatica Ltda.  @Logistics
# 1            Cadillac Fairview Brasil Participacoes Ltda.     1699516
# 2                              Competition Academia Ltda.        2Xfr
# 3       Quickly Travel Agencia de Viagens e Turismo Ltda.         3Mf
# 4                       Glr Consultoria em Sistemas Ltda.          3r
# ...                                                   ...         ...
# 772634             Lobo & de Rizzo Sociedade de Advogados       Paula
# 772690  Amaral, Biazzo, Portela & Zucca - Sociedade de...       Lucas
# 780462            Autuori, Burmann Sociedade de Advogados     Luciano
# 780517             Lobo & de Rizzo Sociedade de Advogados       Paulo
# 780573  Amaral, Biazzo, Portela & Zucca - Sociedade de...       Lucas
#
#                     1              2          3        4     5     6     7  \
# 0               Reply            Srl       None     None  None  None  None
# 1             Ontario            Inc       None     None  None  None  None
# 2       Participacoes          Ltda.       None     None  None  None  None
# 3       Participacoes          Ltda.       None     None  None  None  None
# 4             Capital  Participacoes      Ltda.     None  None  None  None
# ...               ...            ...        ...      ...   ...   ...   ...
# 772634       Cristina       Penteado  Magalhaes  Azevedo  None  None  None
# 772690      Menicelli      Lagonegro       None     None  None  None  None
# 780462      Bernardes        Alberto      Silva     None  None  None  None
# 780517           Jose     Cavalcante    Santana     None  None  None  None
# 780573        Silvino       Craveiro       None     None  None  None  None
#
#            8     9    10    11    12    13
# 0       None  None  None  None  None  None
# 1       None  None  None  None  None  None
# 2       None  None  None  None  None  None
# 3       None  None  None  None  None  None
# 4       None  None  None  None  None  None
# ...      ...   ...   ...   ...   ...   ...
# 772634  None  None  None  None  None  None
# 772690  None  None  None  None  None  None
# 780462  None  None  None  None  None  None
# 780517  None  None  None  None  None  None
# 780573  None  None  None  None  None  None
#
# [15782 rows x 15 columns]

# %%
# Transformando o formato do dataframe para longer considerando apenas a relação empresa-aconista_x
df_5 = pd.melt(
    frame = df_5,
    id_vars = ['Empresa'],
    var_name = 'coluna_referencia',
    value_name = 'nome'
)

# %%
df_5 = df_5.dropna()
df_5 = df_5.drop(columns = ['coluna_referencia'])

# %%
df_5.shape
# Out:
# (57883, 2)

# %%
df_5[400:410]
# Out:
#                                      Empresa       nome
# 400  E.Life Monitor Estudos De Mercado Ltda.  Alexandre
# 401                   Tennessee Carnes Ltda.  Alexandre
# 402               Fortville Vigilancia Ltda.  Alexandre
# 403           Embratop Geo Tecnologias Ltda.  Alexandre
# 404         Restaurante Praca Paulista Ltda.  Alexandre
# 405               Restaurante Praca Jk Ltda.  Alexandre
# 406                  Alkaserv Servicos Ltda.  Alexandre
# 407   Penascal Engenharia e Construcao Ltda.  Alexandre
# 408   Infravias Construcoes e Servicos Ltda.  Alexandre
# 409               Imigrantes Mercantil Ltda.  Alexandre

# %%
# substituir nomes
substituicoes = {
    'Vice': None,
    '(Sócio-Administrador)': None,
    '(Administrador)': None,
    '(Diretor)': None,
    'de': None,
    'da': None,
    'Sócio': None,
    '(Conselheiro)':None,
    '(Tesoureiro)':None,
    '(Administração)':None,
    '(Administração)':None,
    'e':None,
    'com':None,
    'do':None,
    'Informatica':None,
    '(Finanças)':None,
    '(Presidente)' : None,
    'Presidente)':None,
    '(Sócio)' : None,
    'Administração)': None,
    'Investidores)' : None,
    '(Investidores)' : None,
    '(Diretor)':None,
    'Diretor':None,
    'Ltda.':None,
    'Plano':None,
    'Participacoes':None,
    'Recuperacao':None,
    'Judicial':None,
    'International':None,
    'S.A.':None,
    'Company':None,
    'Liquidação':None,
    'em':None,
    'Recuperacao':None

}

## valores_a_substituir = list(substituicoes.keys())

df_5['nome'] = df_5['nome'].replace(substituicoes, regex = False)

## df_5['nome'] = df_5['nome'].replace(valores_a_substituir, None, regex=True)

# %%
resultado = df_5.groupby(['nome'])['nome'].count().reset_index(name='count')
resultado = resultado.sort_values(by='count', ascending=False)
resultado
# Out:
#                nome  count
# 10852         Silva    742
# 10411        Santos    494
# 6226           Jose    490
# 8692       Oliveira    439
# 7437          Maria    436
# ...             ...    ...
# 6945        Lisieri      1
# 2521   Chiarastella      1
# 6943          Lisan      1
# 6942           Lisa      1
# 6415           Kddi      1
#
# [12830 rows x 2 columns]

# %%
df_5.shape
# Out:
# (56851, 2)

# %%
df_5 = df_5.dropna()

# %%
## removendo células com apenas um caracter

df_5 = df_5[df_5['nome'].str.len() > 1]

# %%
df_5[400:405]
# Out:
#                               Empresa       nome
# 401            Tennessee Carnes Ltda.  Alexandre
# 402        Fortville Vigilancia Ltda.  Alexandre
# 403    Embratop Geo Tecnologias Ltda.  Alexandre
# 404  Restaurante Praca Paulista Ltda.  Alexandre
# 405        Restaurante Praca Jk Ltda.  Alexandre

# %%
# Contando a quantidade de nomes por empresa

qtde_nomes_unitarios_empresa = df_5.groupby(['Empresa', 'nome']).size().reset_index(name = 'count')

# %%
qtde_nomes_unitarios_empresa
# Out:
#                                                  Empresa        nome  count
# 0                  1 1 A Flacipel Remocoes de Lixo Ltda.       Fabio      1
# 1                  1 1 A Flacipel Remocoes de Lixo Ltda.     Freitas      1
# 2                  1 1 A Flacipel Remocoes de Lixo Ltda.     Pereira      1
# 3                  1 1 A Flacipel Remocoes de Lixo Ltda.       Urias      1
# 4                  1000 X Servicos Administrativos Ltda.      Eliane      1
# ...                                                  ...         ...    ...
# 42639                  Zurich Industria e Comercio Ltda.      Victor      1
# 42640                  Zurich Industria e Comercio Ltda.  Zadorojuoi      1
# 42641  Zwilling J.A.Henckels Brasil Produtos de Cozin...        Gmbh      2
# 42642  Zwilling J.A.Henckels Brasil Produtos de Cozin...     Trading      1
# 42643  Zwilling J.A.Henckels Brasil Produtos de Cozin...    Zwilling      2
#
# [42644 rows x 3 columns]

# %%
base_final = pd.merge(qtde_nomes_unitarios_empresa, qtde_acionistas_por_empresas,
on = 'Empresa', how = 'left')

# %%
base_final
# Out:
#                                                  Empresa        nome  count_x  \
# 0                  1 1 A Flacipel Remocoes de Lixo Ltda.       Fabio        1
# 1                  1 1 A Flacipel Remocoes de Lixo Ltda.     Freitas        1
# 2                  1 1 A Flacipel Remocoes de Lixo Ltda.     Pereira        1
# 3                  1 1 A Flacipel Remocoes de Lixo Ltda.       Urias        1
# 4                  1000 X Servicos Administrativos Ltda.      Eliane        1
# ...                                                  ...         ...      ...
# 42639                  Zurich Industria e Comercio Ltda.      Victor        1
# 42640                  Zurich Industria e Comercio Ltda.  Zadorojuoi        1
# 42641  Zwilling J.A.Henckels Brasil Produtos de Cozin...        Gmbh        2
# 42642  Zwilling J.A.Henckels Brasil Produtos de Cozin...     Trading        1
# 42643  Zwilling J.A.Henckels Brasil Produtos de Cozin...    Zwilling        2
#
#        count_y
# 0            2
# 1            2
# 2            2
# 3            2
# 4            1
# ...        ...
# 42639        3
# 42640        3
# 42641        2
# 42642        2
# 42643        2
#
# [42644 rows x 4 columns]

# %%
filtro = base_final['Empresa'] == '10 M Group Participacoes S.A.'
base_final[filtro]
# Out:
# Empty DataFrame
# Columns: [Empresa, nome, count_x, count_y]
# Index: []

# %%
base_final['proporcao_nomes_por_qtde_socios'] = base_final['count_x']/base_final['count_y']*100

# %%
base_final[base_final['count_y'] > 2].sort_values(by='proporcao_nomes_por_qtde_socios',ascending=False)
# Out:
#                                                  Empresa        nome  count_x  \
# 35229                   Selina Brazil Hospitalidade S.A.      Selina       10
# 24295        Ludique Et Badin Comercio de Calcados Ltda.    Tchalian        3
# 38728           Tintas Famosas Comercial de Tintas Ltda.    Aggiunti        8
# 34670            Santa Cruz Industrial e Comercial Ltda.       Pires        3
# 20140                      Itavema Europa Veiculos Ltda.      Franco        3
# ...                                                  ...         ...      ...
# 23573             Lobo & de Rizzo Sociedade de Advogados     Cardoso        1
# 23572             Lobo & de Rizzo Sociedade de Advogados   Caravello        1
# 23571             Lobo & de Rizzo Sociedade de Advogados  Cantarella        1
# 23570             Lobo & de Rizzo Sociedade de Advogados        Cano        1
# 1885   Amaral, Biazzo, Portela & Zucca - Sociedade de...          la        1
#
#        count_y  proporcao_nomes_por_qtde_socios
# 35229       10                            100.0
# 24295        3                            100.0
# 38728        8                            100.0
# 34670        3                            100.0
# 20140        3                            100.0
# ...        ...                              ...
# 23573      100                              1.0
# 23572      100                              1.0
# 23571      100                              1.0
# 23570      100                              1.0
# 1885       100                              1.0
#
# [24487 rows x 5 columns]

# %%
# criando o dataframe final
# encontrando o sobrenome com o maior valor em número de ocorrências para cada empresa

idx = base_final.groupby('Empresa')['count_x'].idxmax()

# criando um novo dataframe
df_6 = base_final.loc[idx, ['Empresa', 'nome', 'count_x', 'count_y', 'proporcao_nomes_por_qtde_socios']]

# %%
df_6
# Out:
#                                                  Empresa          nome  \
# 0                  1 1 A Flacipel Remocoes de Lixo Ltda.         Fabio
# 4                  1000 X Servicos Administrativos Ltda.        Eliane
# 9         13A Informatica e Material de Escritorio Ltda.         Costa
# 11               2001 Servicos de Entregas Rapidas Ltda.          Alex
# 15        2Easy Servicos de Processamento de Dados Ltda.        Carlos
# ...                                                  ...           ...
# 42621                 Zunzal Comercio de Alimentos Ltda.       Bottura
# 42627          Zurcher Kantonalbank Representacoes Ltda.  Kantonalbank
# 42630                   Zurich Brasil Capitalizacao S.A.     Insurance
# 42637                  Zurich Industria e Comercio Ltda.         Romao
# 42641  Zwilling J.A.Henckels Brasil Produtos de Cozin...          Gmbh
#
#        count_x  count_y  proporcao_nomes_por_qtde_socios
# 0            1        2                        50.000000
# 4            1        1                       100.000000
# 9            2        2                       100.000000
# 11           1        1                       100.000000
# 15           1        3                        33.333333
# ...        ...      ...                              ...
# 42621        2        3                        66.666667
# 42627        1        1                       100.000000
# 42630        2        2                       100.000000
# 42637        3        3                       100.000000
# 42641        2        2                       100.000000
#
# [5698 rows x 5 columns]

# %%
df_6[df_6['count_y'] > 2].sort_values(by='proporcao_nomes_por_qtde_socios',ascending=False)
# Out:
#                                                  Empresa        nome  count_x  \
# 42637                  Zurich Industria e Comercio Ltda.       Romao        3
# 10513                  Criarte - Educacao Infantil Ltda.     Caserta        3
# 30533                              Pizzaria Camelo Ltda.     Nobrega        4
# 30547           Pizzimenti Ferragens e Ferramentas Ltda.  Pizzimenti        6
# 11516             Digisensor Sistemas de Seguranca Ltda.      Nonaka        3
# ...                                                  ...         ...      ...
# 40427                                  Veirano Advogados     Augusto        5
# 4183   Barbosa, Mussnich e Aragao Advogados (Sao Paul...      Felipe        4
# 3778      Azevedo Sette Advogados Associados (São Paulo)       Souza        5
# 15003  Felsberg e Pedretti Advogados e Consultores Le...    Oliveira        5
# 23693             Lobo & de Rizzo Sociedade de Advogados       Maria        5
#
#        count_y  proporcao_nomes_por_qtde_socios
# 42637        3                       100.000000
# 10513        3                       100.000000
# 30533        4                       100.000000
# 30547        6                       100.000000
# 11516        3                       100.000000
# ...        ...                              ...
# 40427       81                         6.172840
# 4183        66                         6.060606
# 3778        83                         6.024096
# 15003       94                         5.319149
# 23693      100                         5.000000
#
# [1409 rows x 5 columns]

# %%
df_6.to_csv('')

# %%
# pendencias: fazer uma análise dos nomes
